# %% [markdown]
# ## Merge DF Final

# %%
# Para la manipulación de datos 

import pandas as pd
import numpy as np

# %%
# importamos df 

df = pd.read_excel(r"df-final.xlsx")
df
# Out:
#                    Localidad    Latitud  Longitud       Provincia
# 0                    Guadame  36.706119 -4.439046          Málaga
# 1           Puebla de Guzman  37.612887 -7.248890        Huelva\n
# 2                     Huelva  37.257587 -6.948494        Huelva\n
# 3                    Andújar  38.039236 -4.050560            Jaén
# 4                    Carmona  37.471788 -5.641291         Sevilla
# ..                       ...        ...       ...             ...
# 537              Son Servera  39.622273  3.360598  Islas Baleares
# 538                 Santanyi  39.354312  3.129480  Islas Baleares
# 539               Ciutadella  40.000440  3.835237  Islas Baleares
# 540  Sant Josep de sa Talaia  38.904361  1.317810  Islas Baleares
# 541                    Sineu  39.643140  3.011611  Islas Baleares
#
# [542 rows x 4 columns]

# %%
# importamos el df de radiacion 

rad_df = pd.read_excel(r'Radiacion.xlsx')
rad_df
# Out:
#        Fecha    Jaen  Granada  Almeria  Malaga  Cordoba  Sevilla   Cadiz  \
# 0    2010_01   64.11    72.09    82.01   76.72    69.99    73.31   72.40
# 1    2010_02   68.83    67.54    82.87   77.23    78.42    78.10   83.22
# 2    2010_03  127.59   127.75   133.36  122.26   135.62   133.74  138.61
# 3    2010_04  164.50   183.56   179.06  171.33   177.26   177.53  186.95
# 4    2010_05  210.55   219.64   240.51  223.91   229.42   230.64  239.30
# ..       ...     ...      ...      ...     ...      ...      ...     ...
# 127  2020_08  223.84   225.61   209.95  220.73   221.63   228.73  226.89
# 128  2020_09  163.24   168.55   159.60  160.12   164.55   167.44  170.64
# 129  2020_10  132.22   135.39   133.65  131.42   129.83   133.73  137.75
# 130  2020_11   87.43    90.29    88.07   84.71    82.69    84.39   90.64
# 131  2020_12   69.81    72.21    84.74   78.46    70.14    71.32   76.52
#
#      Huelva  Murcia  ...  La Rioja  Vizcaya  Guipuzcoa   Alava  Cantabria  \
# ...

# %%
# vemos si hay nas

df.info()
rad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Localidad  542 non-null    object
#  1   Latitud    542 non-null    float64
#  2   Longitud   542 non-null    float64
#  3   Provincia  542 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 17.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Fecha                   132 non-null    object
#  1   Jaen                    132 non-null    float64
#  2   Granada                 132 non-null    float64
#  3   Almeria                 132 non-null    float64
#  4   Malaga                  132 non-null    float64
#  5   Cordoba                 132 non-null    float64
# ...

# %%
df.Provincia = df.Provincia.str.replace('\n',"", regex=True)
df.Provincia.value_counts()
# Out:
# Madrid            52
# Valencia          33
# Barcelona         24
# Alicante          17
# Sevilla           17
# Asturias          16
# Zaragoza          16
# Cáceres           16
# Huesca            15
# Cantabria         15
# Tarragona         14
# León              13
# Vizcaya           13
# La Coruña         12
# Navarra           12
# Badajoz           11
# Cádiz             11
# Ciudad Real       11
# Islas Baleares    11
# Zamora            11
# Lérida            11
# Lugo              10
# Toledo            10
# Málaga            10
# Murcia            10
# Teruel            10
# Salamanca          9
# Orense             9
# Granada            9
# Álava              9
# Valladolid         9
# Huelva             8
# Pontevedra         8
# Gipuzcoa           8
# Burgos             8
# Castellón          8
# Cuenca             7
# Soria              7
# La Rioja           6
# Almería            6
# Palencia           5
# Córdoba            5
# Gerona             5
# ...

# %%
# Cambiamos el tipo a fecha 
rad_df['Fecha'] = rad_df['Fecha'].str.replace("_", "-", regex=True)
rad_df
# Out:
#        Fecha    Jaen  Granada  Almeria  Malaga  Cordoba  Sevilla   Cadiz  \
# 0    2010-01   64.11    72.09    82.01   76.72    69.99    73.31   72.40
# 1    2010-02   68.83    67.54    82.87   77.23    78.42    78.10   83.22
# 2    2010-03  127.59   127.75   133.36  122.26   135.62   133.74  138.61
# 3    2010-04  164.50   183.56   179.06  171.33   177.26   177.53  186.95
# 4    2010-05  210.55   219.64   240.51  223.91   229.42   230.64  239.30
# ..       ...     ...      ...      ...     ...      ...      ...     ...
# 127  2020-08  223.84   225.61   209.95  220.73   221.63   228.73  226.89
# 128  2020-09  163.24   168.55   159.60  160.12   164.55   167.44  170.64
# 129  2020-10  132.22   135.39   133.65  131.42   129.83   133.73  137.75
# 130  2020-11   87.43    90.29    88.07   84.71    82.69    84.39   90.64
# 131  2020-12   69.81    72.21    84.74   78.46    70.14    71.32   76.52
#
#      Huelva  Murcia  ...  La Rioja  Vizcaya  Guipuzcoa   Alava  Cantabria  \
# ...

# %%
# Hacemos un transpose de las columnas 
# Y ponemos las nuevas columnas
rad_df = rad_df.T.reset_index()
rad_df.head(10)
headers=rad_df.iloc[0]
rad_df.columns = headers
rad_df = rad_df.drop(rad_df.index[0])
rad_df=rad_df.rename(columns={'Fecha':'Provincia'})
rad_df
# Out:
#      index        0        1        2        3        4        5        6  \
# 0    Fecha  2010-01  2010-02  2010-03  2010-04  2010-05  2010-06  2010-07
# 1     Jaen    64.11    68.83   127.59    164.5   210.55   216.39   246.28
# 2  Granada    72.09    67.54   127.75   183.56   219.64   223.24    247.3
# 3  Almeria    82.01    82.87   133.36   179.06   240.51   237.05   238.35
# 4   Malaga    76.72    77.23   122.26   171.33   223.91   229.21   235.81
# 5  Cordoba    69.99    78.42   135.62   177.26   229.42   220.25   253.76
# 6  Sevilla    73.31     78.1   133.74   177.53   230.64   224.26   249.54
# 7    Cadiz     72.4    83.22   138.61   186.95    239.3   228.25   244.39
# 8   Huelva    70.01    83.17    132.8   185.78   234.91   226.77   252.72
# 9   Murcia    73.88    79.16    125.8   159.36   218.41   217.38   234.35
#
#          7        8  ...      122      123      124      125      126  \
# 0  2010-08  2010-09  ...  2020-03  2020-04  2020-05  2020-06  2020-07
# ...

# %%
headers=rad_df.iloc[0]
rad_df.columns = headers
rad_df = rad_df.drop(rad_df.index[0])
rad_df=rad_df.rename(columns={'Fecha':'Provincia'})
rad_df
# Out:
# 0                Provincia 2010-01 2010-02 2010-03 2010-04 2010-05 2010-06  \
# 1                     Jaen   64.11   68.83  127.59   164.5  210.55  216.39
# 2                  Granada   72.09   67.54  127.75  183.56  219.64  223.24
# 3                  Almeria   82.01   82.87  133.36  179.06  240.51  237.05
# 4                   Malaga   76.72   77.23  122.26  171.33  223.91  229.21
# 5                  Cordoba   69.99   78.42  135.62  177.26  229.42  220.25
# 6                  Sevilla   73.31    78.1  133.74  177.53  230.64  224.26
# 7                    Cadiz    72.4   83.22  138.61  186.95   239.3  228.25
# 8                   Huelva   70.01   83.17   132.8  185.78  234.91  226.77
# 9                   Murcia   73.88   79.16   125.8  159.36  218.41  217.38
# 10                 Caceres    64.2   71.91  120.09  174.57  214.18  217.31
# 11                 Badajoz   63.51   75.81  118.83  178.25  215.48  221.74
# ...

# %%
# Hacemos regex 
rad_df.Provincia = rad_df.Provincia.str.replace('Jaen', 'Jaén', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Almeria', 'Almería', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Malaga', 'Málaga', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Cadiz', 'Cádiz', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Caceres', 'Cáceres', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Castellon', 'Castellón', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Avila', 'Ávila', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Leon', 'León', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Lerida', 'Lérida', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Cordoba', 'Córdoba', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Alava', 'Álava', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Lleida', 'Lérida', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Baleares', 'Islas Baleares', regex=True)
rad_df.Provincia = rad_df.Provincia.str.replace('Gipuzcoa', 'Guipuzcoa', regex=True)

# %%
# Hacemos el merge
total_df = pd.merge(df, rad_df, how='left', on='Provincia')
total_df
# Out:
#                    Localidad    Latitud  Longitud       Provincia 2010-01  \
# 0                    Guadame  36.706119 -4.439046          Málaga   76.72
# 1           Puebla de Guzman  37.612887 -7.248890          Huelva   70.01
# 2                     Huelva  37.257587 -6.948494          Huelva   70.01
# 3                    Andújar  38.039236 -4.050560            Jaén   64.11
# 4                    Carmona  37.471788 -5.641291         Sevilla   73.31
# ..                       ...        ...       ...             ...     ...
# 537              Son Servera  39.622273  3.360598  Islas Baleares   64.97
# 538                 Santanyi  39.354312  3.129480  Islas Baleares   64.97
# 539               Ciutadella  40.000440  3.835237  Islas Baleares   64.97
# 540  Sant Josep de sa Talaia  38.904361  1.317810  Islas Baleares   64.97
# 541                    Sineu  39.643140  3.011611  Islas Baleares   64.97
#
#     2010-02 2010-03 2010-04 2010-05 2010-06  ... 2020-03 2020-04 2020-05  \
# ...
